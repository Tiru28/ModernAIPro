# %% [markdown]
# <a href="https://colab.research.google.com/github/Tiru28/ModernAIPro/blob/main/Agentic_AI_(North_America_%7C_December_2025).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 15-Hour Bootcamp Plan: Agentic AI in Business
#
# ---
#
# ## Overview
# This bootcamp covers key concepts, design, architecture, and practical applications of Agentic AI. Participants will gain hands-on experience and develop a capstone project, applying learned concepts to build an AI agent for stock selection.
#
# ---
#
# ## Schedule
#
# ### **Friday: 4:30 PM - 6:30 PM** (All times in PST)
# [Slides](https://docs.google.com/presentation/d/1bYrhKzT6TuU4v6ebeWz9uq1pZP12PA0Ur1pxpA05ulA/edit#slide=id.g3248f27b9c8_0_18)
#
# - [Mini Project 1: First LLM app](https://colab.research.google.com/drive/14I39CnLNSZYekRVzArEuE2Q1Sryhov2i#scrollTo=BF0-EoHaRS4W)
# - Trying out a quick model locally: https://ollama.com/
# - Find the terminal/shell and try it there: **ollama run deepseek-r1:1.5b**
# - Playing a [simple AI game](https://colab.research.google.com/drive/1gCjPmLF64S8qK3kCPmKfAWzy4f06oqaR#scrollTo=eS1CpZKoG9C0)
#
#
# - [Mini Project 2: First Chatbot](https://colab.research.google.com/drive/1q14coEFNdJ6rgk8Nd0sZ4ymnufbDlqaq?usp=sharing)
# - [Mini Project 3: LLM with real time data](https://colab.research.google.com/drive/1mK9R-aJFWwREhuH99if9okpjxBhw2rt3?usp=sharing)
# - [Mini Project 4: LLM with memory](https://colab.research.google.com/drive/1nIQbid1SBPCkoQhjysgbXGClLZ4I8sy1?usp=sharing)
# - [Praciting Similiarity search with Vector DB](https://colab.research.google.com/drive/1cQr0ssoXcYxhJ5MvhtoYwmG67g3l0P5W?usp=sharing)
# - [LLM with Multimodality](https://colab.research.google.com/drive/1EUu7lS6r6DUEqoxnlobiOh5FHQuCm2r6)
# - [First agent with the ReAct Framework](https://colab.research.google.com/drive/1IK5JvjczY5QsTbqC7SWy206ZGFC4k5nw?usp=sharing)
#
#
# - Further collections: https://github.com/NirDiamant/GenAI_Agents
#
# ### **Saturday: 8:30 AM - 3:30 PM**
#
# #### **8:30AM - 10:30AM**: Fundamentals of Machine Learning
# - Overview of machine learning categories and problem-solving approaches.
# - Key algorithms and their applications.
# - Setting the stage for autonomous AI agents.
# - Setting the stage for autonomous AI agents.
# [Slides](https://drive.google.com/file/d/1axsCb0rdgK-zggrFcFfHZQvjgvIEsm3V/view)
# [Slides 2](https://drive.google.com/file/d/1yYNqFv8wk_KXQ-7qkEOzMIhdTv_iSdE4/view)
#
# #### **10:40 AM - 12:10 PM**: Building applications on LLMs.
#
# [My first agent](https://colab.research.google.com/drive/1IK5JvjczY5QsTbqC7SWy206ZGFC4k5nw#scrollTo=XNvYqSYcY_0u)
#
# [Slides](https://docs.google.com/presentation/d/1aVakLkyuHwE3vt4wdTRqZrpRGeItqdbNAg0s5ycjs8Q/edit#slide=id.g1e2ee25a6cc_0_0)
#
# ---
# **Lunch Break: 12:10 PM - 12:45 PM**
#
# #### **12:45 PM - 2:15 PM**: Strategic Importance of Agentic AI in Business
# - Challenges and opportunities presented by AI agents in organizational contexts.
# - Forecasting emerging trends and business impacts.
# - Aligning AI agent implementation with strategic goals.
# [Slides](https://docs.google.com/presentation/d/1spbvGJV5en_DN_dwUUlGaM1tEu1eOILd2dH4lr5EpTc/edit)
# [Document](https://docs.google.com/document/d/1OcbMXEEdzHkbmrw864bbpSfwpYBY382YMp7ehHpGB60/edit?tab=t.0)
#
# #### **2:25 PM - 3:30 PM**: Understanding RAG & Agentic RAG
# - Case studies of AI agents across industries.
# - Overview of frameworks: Microsoft AutoGen, LangGraph, and CrewAI.
# - Strategies for integrating AI agents into business operations.
# [Applications](https://docs.google.com/document/d/1OcbMXEEdzHkbmrw864bbpSfwpYBY382YMp7ehHpGB60/edit?tab=t.0)
# [Agentic RAG 1](https://colab.research.google.com/drive/1npEnRSYXB4GC5nbRPowhkPCG7S6fhBRb)
# [Agentic RAG 2](https://colab.research.google.com/drive/15ewzaL4odo0jVqZro65AqVkWDI-_8Y3f#scrollTo=cK3qVlGE2g5e)
# [Slide](https://docs.google.com/presentation/d/1Lp6OrpJzi0tVd_BM9Vw6dAa6eNGgk84kOsFQ_sHgHiM/edit#slide=id.g2817a1d796a_0_0)
# ---
#
# ### **Sunday: 8:30 AM - 3:30 PM**
# #### **8:30 AM - 10:30 AM**: Natural Language Processing and Transformers
# - Understanding the role of NLP in Agentic AI.
# - Basics of transformers and their relevance to AI agents.
# - Practical examples of NLP applications in business.
#
# #### **10:40 AM - 12:10 PM**: Design and Architecture of Autonomous AI Agents
#
# - Core components and architectures of Multiagent Systems.
# - Decision-making processes and machine learning techniques.
# - Frameworks for developing and deploying agentic AI solutions.
#
# [Autogen](https://colab.research.google.com/drive/1GKnxasdBqh81YooV8oCqekTwB3YYTXuY)
#
# [Langgraph](https://colab.research.google.com/drive/15UuvEmi955OsIMTknxwh3pn3nE-XJptr?usp=sharing#scrollTo=ecXmrS1Be02S)
# [Crew of agents](https://colab.research.google.com/drive/1ACt6TPg8SdhtXD1xOQNpIWS4RjrIQKfW)
#
#
#
#
# **Lunch Break: 12:10 PM - 12:45 PM**
#
# ---
#
# #### **12:45 AM - 2:10 PM**: 48 Low hanging applications for Agentic AI.
# What are the key characteristics of tasks that will be done by Agents?
# 1. Clear identification of where decisions have to be made.
# 2. Tasks at the leaf nodes of an organizagtion
# 3. Instant validation
#
# [Evaluation in enterprises](https://colab.research.google.com/drive/1ohdsyb2athEkRawI2HF-6kBxhdFF8HTk)
#
# [Discussing 48 applications sectory by sector](https://docs.google.com/document/d/1OcbMXEEdzHkbmrw864bbpSfwpYBY382YMp7ehHpGB60/edit?tab=t.0)
#
# ---
# #### **2:20 AM - 3:30 PM**: Intro Capstone Project: Stock-Picking Agent
# - Utilizing news sentiment analysis, fundamental analysis, and technical indicators.
# - Hands-on experience integrating data sources and analytical methods.
# - Collaborative work to build and deploy a functional stock-picking AI agent.
#
# ---
#
# ## Detailed Sessions
#
# ### **Introduction to Agentic AI**
# - Key Concepts
# - Multiagent Systems
# - Evolution and Relevance
#
# ### **Strategic Importance**
# - Business Alignment
# - Trends and Forecasts
# - Challenges and Opportunities
#
# ### **Design and Architecture**
# - Multiagent System Components
# - Decision-Making and ML
# - Framework Development
#
# ### **Frameworks**
# - Microsoft AutoGen, LangGraph, CrewAI
# - Features and Use Cases
# - Framework Selection
#
# ### **Applications**
# - Integration Strategies
# - Industry-Specific Examples
#
# ### **RAG Integration**
# - Enhancing Performance
# - Practical Use Cases
#
# ### **Leadership in AI**
# - Change Management
# - Building Trust
# - Organizational Preparation
#
# ---
#
# ## Hands-On Activities
# - Building Simple AI Agents
# - Multiagent System Simulations
# - Implementing Solutions for Low-Hanging Fruits (e.g., Code Generation, Sales Outreach)
#
# ---
#
# ## Capstone Project
# - **Title**: Stock-Picking Agent
# - **Objectives**: Apply learned concepts to build a practical AI agent.
# - **Methods**: News sentiment analysis, fundamental analysis, and technical indicators.
# - **Outcome**: Functional agent ready for deployment.
#
# ---
#
# ### **Optional Add-On Sessions** (for extended learning)
# - Advanced NLP techniques.
# - Integrating RAG for enterprise data solutions.
# - Framework deep dives for specific use cases.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
